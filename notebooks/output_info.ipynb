# %% [markdown]
# ## Look at details of model output

# %% [markdown]
# ### Imports and Installations

# %%
#pip install pandas

# %%
#pip install matplotlib

# %%
#pip install lxml

# %%
import pandas as pd
import matplotlib.pyplot as plt
import lxml.etree as ET
import xml.etree.ElementTree as et
#import ElementTree as ET

# %% [markdown]
# ### Emission Output Basic Model

# %%
df_cols = ["time","id", "eclass", "CO2", "CO", "HC", "PMx", "NOx","PMx", "fuel","electricity", "route" ,"type" ,"noise", "waiting", "lane" , "pos" , "speed", "angle", "x", "route", "y"]

# %%
def parse_XML(xml_file, df_cols): 
    """Parse the input XML file and store the result in a pandas 
    DataFrame with the given columns. 
    """
    out_df = pd.DataFrame(columns = df_cols)
    xtree = et.parse(xml_file)
    xroot = xtree.getroot()
    rows = []
    
    for node in xroot: 
        
        j = 0
        for element in node:
            res = []
            res.append(node.attrib.get(df_cols[0]))
            
            for el in df_cols[1:]:
                if node is not None and element.get(el) is not None:
                    res.append(element.get(el))
                else: 
                    res.append(None)
            rows.append({df_cols[i]: res[i] 
                        for i, _ in enumerate(df_cols)})
    
            out_df.loc[len(out_df)] = rows[j] 
            j += 1
        
        #print(node.attrib.get(df_cols[0]))
        
    return out_df

# %%
emission_info = parse_XML('../src/data/2023-04-06-17-43-39emission_info.xml', df_cols)

# %%
emission_info.to_csv('../src/data/emission_info.csv')

# %%
emission_info
# Out:
#          time          id            eclass       CO2      CO    HC   PMx
# 0        0.00       bike0      Zero/default      0.00    0.00  0.00  0.00  \
# 1        0.00        bus0        HBEFA3/Bus   5286.11   20.17  4.85  2.01
# 2        0.00       moto0  HBEFA3/LDV_G_EU6   1228.61  179.19  0.64  0.17
# 3        0.00       ship0  HBEFA3/HDV_D_EU0  10898.83   19.90  8.01  4.68
# 4        0.00  tram_2:0.0      Zero/default      0.00    0.00  0.00  0.00
# ...       ...         ...               ...       ...     ...   ...   ...
# 377696  27.00      truck1        HBEFA3/HDV  11876.36   19.65  0.00  2.57
# 377697  27.00      truck2        HBEFA3/HDV  15072.91   23.11  0.00  2.93
# 377698  27.00      truck3        HBEFA3/HDV      0.00    0.00  0.00  0.00
# 377699  27.00      truck4        HBEFA3/HDV  16710.95   24.53  0.00  2.99
# 377700  27.00      truck5        HBEFA3/HDV  10401.75   17.96  0.00  2.38
#
#            NOx   PMx     fuel  ...             type  noise waiting
# 0         0.00  0.00     0.00  ...     bike_bicycle   0.00    0.00  \
# 1        60.75  2.01  1671.11  ...          bus_bus  67.11    0.00
# 2         0.31  0.17   391.94  ...  moto_motorcycle  55.94    0.00
# 3       146.75  4.68  3429.41  ...        ship_ship  69.15    0.00
# 4         0.00  0.00     0.00  ...             tram   0.00    0.00
# ...        ...   ...      ...  ...              ...    ...     ...
# 377696  111.77  2.57  3735.85  ...      truck_truck  71.39    0.00
# 377697  135.41  2.93  4741.41  ...      truck_truck  72.86    0.00
# 377698    0.00  0.00     0.00  ...      truck_truck  74.13    0.00
# 377699  142.21  2.99  5256.62  ...      truck_truck  75.72    0.00
# 377700   99.51  2.38  3271.94  ...      truck_truck  71.24    0.00
#
#                                                  lane    pos  speed   angle
# 0                                       240348395#3_1   1.70   0.00  140.51  \
# 1                                       257676226#1_1   3.98   0.00  129.84
# 2                                       107085651#1_1   2.30   0.00  121.18
# 3                                       176021667#2_0  17.10   4.12   29.92
# 4                                       189075375#3_0  22.10   0.00  292.81
# ...                                               ...    ...    ...     ...
# 377696  :cluster_1928067799_2302357563_2302357564_3_0  20.35   7.08  187.25
# 377697                                   97301275#0_1   7.66   8.23  211.46
# 377698                                    127607593_1  50.68  13.22  148.19
# 377699                                 150393267#10_0  50.79  13.38  155.24
# 377700                                  258979265#1_2   7.40   7.72  121.04
#
#                x          route         y
# 0       15499.17   !bike0!var#1  54231.16
# 1       14743.69    !bus0!var#1  54292.04
# 2       14718.14   !moto0!var#1  54990.53
# 3       14227.27         !ship0  53113.66
# 4       14782.45       tram_2:0  56152.10
# ...          ...            ...       ...
# 377696  13853.62  !truck1!var#1  56215.76
# 377697  14479.38  !truck2!var#1  55597.46
# 377698  15724.27  !truck3!var#1  53871.02
# 377699  13473.70  !truck4!var#1  55507.72
# 377700  14284.67  !truck5!var#1  55522.81
#
# [377701 rows x 22 columns]

# %%
emission_info.id.unique()
# Out:
# array(['bike0', 'bus0', 'moto0', 'ship0', 'tram_2:0.0', 'tram_3:1.0',
#        'truck0', 'veh0', 'truck1', 'veh1', 'bike1', 'moto1', 'truck2',
#        'veh2', 'truck3', 'veh3', 'bike2', 'moto2', 'truck4', 'veh4',
#        'bike3', 'moto3', 'truck5', 'veh5', 'truck6', 'veh6', 'bike4',
#        'moto4', 'veh7', 'truck8', 'veh8', 'bike5', 'moto5', 'truck9'],
#       dtype=object)
